# %% [markdown]
# # Step 0: Import python libraries
#
# WARNING: image plot need to be fixed

# %%
import requests
import matplotlib.pyplot as plt
import numpy as np
import os
import psutil

from astropy.io import fits

# %% [markdown]
# # Step 1: Search for and store BepiColombo data products using the search API

# %%
q_string = (
    '((pds:Science_Facets.pds:wavelength_range eq "Visible") '
    'and (pds:Science_Facets.pds:wavelength_range eq "Visible") '
    'and (pds:Header.pds:parsing_standard_id eq "FITS 3.0") '
    'and (pds:Time_Coordinates.pds:start_date_time gt "2022-04-30T00:00:00Z"))'
)

params = {
    'q': q_string,
    'limit': 3000
}

headers = {
    'Accept': 'application/json'
}

response = requests.get(
    'https://pds.nasa.gov/api/search/1/products',
    headers=headers,
    params=params
)

resp_data = response.json()['data']

# %% [markdown]
# ### Store image URLS in a list format to load for visualization

# %%
urls = [prod['properties']['ops:Data_File_Info.ops:file_ref'][0] for prod in resp_data]
urls[0]
# Out:
# 'https://archives.esac.esa.int/psa/repo/esa/psa/juice_jmc/data_raw/2025-09-11/jmc_raw_hk_cam_1_hk_report_20250909/0.2/jmc_raw_hk_cam_1_hk_report_20250909__0_2.fits'

# %% [markdown]
# # Step 2: Grid Visualization of Image Data
# Specify the page you would like to see with the page parameter below. Each page displays 48 image products. The current time query is viewing BC's mercury flyby on the 23rd of June 2022.

# %%
#EDIT THIS VARIABLE TO CHANGE PAGES
PAGE = 0
#EDIT THIS VARIABLE TO CHANGE SUBSAMPLING
SUBSAMPLING_RATE = 7 #Indicates how many pixels to skip when plotting


NUM_COLUMNS = 4
NUM_ROWS = 8
size = NUM_COLUMNS*NUM_ROWS
fig, axs = plt.subplots(NUM_ROWS, NUM_COLUMNS , figsize=(8, 24))

for i, image_path in enumerate(urls[size*PAGE:size*(PAGE+1)]):
    response = requests.get(image_path)
    with fits.open(image_path) as hdul:
        image_data = hdul[1].data
    row, col = divmod(i,NUM_COLUMNS)
    # reshape the images, not sure why it is needed since astropy 7
    #image_data.reshape(hdul[1].header['NAXIS1'], hdul[1].header['NAXIS2'])
    axs[row, col].imshow(image_data[0::SUBSAMPLING_RATE,0::SUBSAMPLING_RATE], cmap='gray')
    #Split the lid by ':' and select the last part of the lid for each image title
    axs[row, col].set_title(resp_data[i]['properties']['lid'][0].split(':')[5], fontsize = 4)
    #Free up memory
    del image_data

for ax in axs.flat:
    ax.label_outer()

plt.suptitle('urn:esa:psa:bc_mtm_mcam:data_raw:', fontsize=16,y=1.01)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[38], line 19
#      16 row, col = divmod(i,NUM_COLUMNS)
#      17 # reshape the images, not sure why it is needed since astropy 7
#      18 #image_data.reshape(hdul[1].header['NAXIS1'], hdul[1].header['NAXIS2'])
# ---> 19 axs[row, col].imshow(image_data[0::SUBSAMPLING_RATE,0::SUBSAMPLING_RATE], cmap='gray')
#      20 #Split the lid by ':' and select the last part of the lid for each image title
#      21 axs[row, col].set_title(resp_data[i]['properties']['lid'][0].split(':')[5], fontsize = 4)
#
# File ~/PycharmProjects/search-api-notebook/venv312/lib/python3.12/site-packages/astropy/io/fits/fitsrec.py:536, in FITS_rec.__getitem__(self, key)
#     531     return self.field(key)
#     533 # Have to view as a recarray then back as a FITS_rec, otherwise the
#     534 # circular reference fix/hack in FITS_rec.field() won't preserve
#     535 # the slice.
# --> 536 out = self.view(np.recarray)[key]
#     537 if type(out) is not np.recarray:
#     538     # Oops, we got a single element rather than a view. In that case,
#     539     # return a Record, which has no __getstate__ and is more efficient.
#     540     return self._record_type(self, key)
#
# File ~/PycharmProjects/search-api-notebook/venv312/lib/python3.12/site-packages/numpy/core/records.py:509, in recarray.__getitem__(self, indx)
#     508 def __getitem__(self, indx):
# --> 509     obj = super().__getitem__(indx)
#     511     # copy behavior of getattr, except that here
#     512     # we might also be returning a single element
#     513     if isinstance(obj, ndarray):
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
hdul = fits.open(image_path)

# %%
hdul[1].header
# Out:
# XTENSION= 'TABLE   '
# BITPIX  =                    8
# NAXIS   =                    2
# NAXIS1  =                   71
# NAXIS2  =                 3456
# PCOUNT  =                    0
# GCOUNT  =                    1
# TFIELDS =                    9
# TTYPE1  = 'TIME_UTC'
# TBCOL1  =                    2
# TFORM1  = 'A24     '
# TUNIT1  = 'None    '
# TTYPE2  = 'TIME_OBT'
# TBCOL2  =                   27
# TFORM2  = 'A18     '
# TUNIT2  = 'None    '
# TTYPE3  = 'FPGA_MAJOR_VERSION'
# TBCOL3  =                   46
# TFORM3  = 'I2      '
# TUNIT3  = 'None    '
# TTYPE4  = 'FPGA_MINOR_VERSION'
# TBCOL4  =                   49
# TFORM4  = 'I2      '
# TUNIT4  = 'None    '
# TTYPE5  = 'PGA_OFFSET'
# TBCOL5  =                   52
# TFORM5  = 'I2      '
# TUNIT5  = 'None    '
# TTYPE6  = 'PGA_GAIN'
# TBCOL6  =                   55
# TFORM6  = 'I1      '
# TUNIT6  = 'None    '
# TTYPE7  = 'EXPOSURE_TIME'
# TBCOL7  =                   57
# TFORM7  = 'I5      '
# TUNIT7  = 'ms      '
# TTYPE8  = 'TEMPERATURE'
# TBCOL8  =                   63
# TFORM8  = 'I4      '
# TUNIT8  = 'None    '
# TTYPE9  = 'SRAM_BIST'
# TBCOL9  =                   68
# TFORM9  = 'I1      '
# TUNIT9  = 'None    '

# %%
hdul[1].header['NAXIS1']
# Out:
# 71

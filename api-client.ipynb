# %% [markdown]
# # PDS federated API demo
#
# Browse an archive from bundle to observational product data
#
# <i>TO BE DONE and DEMONSTRATED APRIL 2021</i>

# %%
from __future__ import print_function
import pds_api_client
from pds_api_client.rest import ApiException
from pds_api_client import Configuration
from pprint import pprint

# %% [markdown]
# ## Create an instance of the API class

# %%
configuration = Configuration()
# dev
#configuration.host = 'http://localhost:8080/'
# gamma
configuration.host = 'http://pds-gamma.jpl.nasa.gov/api/'
api_instance = pds_api_client.CollectionsApi(pds_api_client.ApiClient(configuration))

# %% [markdown]
# ## Request the API

# %%
try:
    # capabilities api entry point, list the resources provided by the current API end-point.
    api_response = api_instance.get_collection(q="", start=0, limit=20)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling CollectionsApi->get_collection: %s\n" % e)
# Out:
# {'data': [{'description': None,
#            'id': 'urn:nasa:pds:izenberg_pdart14_meap:data_imagecube::1.0',
#            'investigations': None,
#            'metadata': {'creation_date_time': '2016-04-08T00:00:00Z',
#                         'label_url': '/Users/loubrieu/tmp/pds-registry-app/target/v11400.patched/dph_example_archive/data_imagecube/collection_imagecube_inventory.csv',
#                         'update_date_time': None,
#                         'version': '1.0'},
#            'observing_system_components': None,
#            'properties': {'_package_id': '8c90a36e-1125-4852-af03-291c100e6ede',
#                           'lid': 'urn:nasa:pds:izenberg_pdart14_meap:data_imagecube',
#                           'lidvid': 'urn:nasa:pds:izenberg_pdart14_meap:data_imagecube::1.0',
#                           'ops:Data_File_Info.ops:creation_date_time': '2021-03-04T19:31:26Z',
# ...
